# %% [markdown]
# **Arithmetic Operations**

# %%
# Addition
5 + 2
# Out:
# 7

# %%
# Subtraction
5 - 2
# Out:
# 3

# %%
# Multiplication 
5 * 2
# Out:
# 10

# %%
# Division (float)
5 / 2
# Out:
# 2.5

# %%
# Division (floor)
5 // 2
# Out:
# 2

# %%
# Modulus
5 % 2
# Out:
# 1

# %%
# Exponentiation
5 ** 2
# Out:
# 25
