# %% [markdown]
# **Exercise 003**
#
# Write a program that reads two numbers and shows the sum between them.

# %%
n1 = int(input('Enter a number: '))
n2 = int(input('Enter another number: '))
s = n1 + n2
print('The sum between {} and {} is equal to {}.'.format(n1, n2, s))
# Out:
# Enter a number: 7
# Enter another number: 3
# The sum between 7 and 3 is equal to 10.
