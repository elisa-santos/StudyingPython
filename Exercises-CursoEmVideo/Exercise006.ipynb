# %% [markdown]
# **Exercise 006**
#
# Create an algorithm that reads a number and shows its double, triple, and square root.

# %%
n = int(input('Enter a number: '))
print('The double of {} is {}, the triple is {}, and the square root is {:.2f}.'.format(n, n*2, n*3, n**(1/2)))
# Out:
# Enter a number: 9
# The double of 9 is 18, the triple is 27, and the square root is 3.00.
